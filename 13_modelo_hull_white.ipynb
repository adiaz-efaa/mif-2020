# %% [markdown]
# # Modelo Hull-White

# %% [markdown]
# ## Ecuaciones del Modelo

# %% [markdown]
# El modelo de Hull - White es una extensión al modelo de Vasicek. La ecuación diferencial estocástica para la evolución de la tasa instantánea en la medida ajustada por riesgo es:
#
# $$
# \begin{equation}
# dr_t=\left(\theta_t-\gamma^* r_t\right)dt+\sigma dX_t
# \end{equation}
# $$
#
# La función $\theta_t$, que se puede interpretar como un nivel de reversión a la media variable en el tiempo, se calibra para ajustar perfectamente el valor de mercado de los bonos cupón cero.
#
# Después de eso, quedan aún dos grados de libertad, $\gamma^*$ y $\sigma$, para calibrar la estructura de volatilidades.

# %% [markdown]
# ### Fórmula para $\theta_t$

# %% [markdown]
# La función $\theta_t$, que permite obtener los precios de mercado de los bonos cupón cero está dada por:
#
# $$
# \begin{equation}
# \theta_t=\frac{\partial f\left(0,t\right)}{\partial t}+\gamma^*f\left(0,t\right)+\frac{\sigma^2}{2\gamma^*}\left[1-\exp\left(-2\gamma^* T\right)\right]
# \end{equation}
# $$

# %% [markdown]
# Recordar que:
#
# $$
# \begin{equation}
# f(t,T)=-\frac{\partial\log P(t,T)}{\partial T} \\
# P(t,T)=\exp\left[-r\left(t,T\right)\left(T-t\right)\right]
# \end{equation}
# $$
#
# por lo tanto,
#
# $$
# \begin{equation}
# -\log P\left(t,T\right)=r\left(t,T\right)\left(T-t\right) \\
# -\frac{\partial \log P\left(t,T\right)}{\partial T}=\frac{\partial r\left(t,T\right) }{\partial T}\left(T-t\right)+r\left(t,T\right)
# \end{equation}
# $$
#
# finalmente,
#
# $$
# \frac{\partial f\left(0,t\right)}{\partial t}=\frac{\partial^2 r\left(0,t\right) }{\partial t^2}t+2\frac{\partial r\left(0,t\right) }{\partial t}
# $$

# %% [markdown]
# ### Fórmulas para Bonos Cero Cupón

# %% [markdown]
# La fórmula para la valoración de bonos cero cupón en el modelo de Hull - White es la siguiente:
#
# $$
# \begin{equation}
# Z\left(r_t,t,T\right)=\exp\left[A\left(t,T\right)-B\left(t,T\right)r_t\right]
# \end{equation}
# $$
#
# $$
# \begin{equation}
# B\left(t,T\right)=\frac{1}{\gamma^*}\left[1-\exp\left(-\gamma^* T\right)\right)]
# \end{equation}
# $$
#
# $$
# \begin{equation}
# A\left(t,T\right)=\log\frac{Z\left(r_0,0,T\right)}{Z\left(r_0,0,t\right)}+B\left(t,T\right)f\left(0,t\right)-\frac{\sigma^2}{4\gamma^*}B\left(t,T\right)^2\left[1-\exp\left(-2\gamma^* T\right)\right)]
# \end{equation}
# $$

# %% [markdown]
# ### Fórmulas para Calls y Puts sobre Bonos Cupón Cero

# %% [markdown]
# Son las mismas que para el modelo de Vasicek, para una call:
#
# $$
# \begin{equation}
# Call\left(r_0,0\right)=Z\left(r_0,0,T_O\right)\left[\frac{Z\left(r_0,0,T_B\right)}{Z\left(r_0,0,T_O\right)}N\left(d_1\right)-KN\left(d_2\right)\right]
# \end{equation}
# $$
#
#
# $$
# \begin{equation}
# d_1=\frac{\log\left(\frac{Z\left(r_0,0,T_B\right)}{KZ\left(r_0,0,T_O\right)}\right)+\frac{1}{2}S_Z\left(T_O\right)^2}{\sqrt{S_Z\left(T_O\right)}}
# \end{equation}
# $$
#
#
# $$
# \begin{equation}
# d_2=d_1-S_Z\left(T_O\right)
# \end{equation}
# $$
#
#
# $$
# \begin{equation}
# S_Z\left(T_O\right)=B\left(T_O,T_B\right)\sqrt{\frac{\sigma^2}{2\gamma^*}\left(1-\exp\left(-2\gamma^* T_O\right)\right)}
# \end{equation}
# $$
#
# Y para una put:
#
# $$
# \begin{equation}
# Put\left(r_0,0\right)=Z\left(r_0,0,T_O\right)\left[KN\left(-d_2\right)-\frac{Z\left(r_0,0,T_B\right)}{Z\left(r_0,0,T_O\right)}N\left(-d_1\right)\right]
# \end{equation}
# $$
#
# y los mismos valores anteriores para $d_1$ y $d_2$.

# %% [markdown]
# ## Implementación del Modelo

# %%
from finrisk import QC_Financial_3 as Qcf
from scipy.interpolate import interp1d
from modules import auxiliary as aux
from numpy import random as rnd
from typing import List, Tuple
import plotly.express as px
import pandas as pd
import numpy as np
import math

# %%
frmt = {'tasa': '{:.4%}', 'df': '{:.6%}'}

# %% [markdown]
# Veamos la construcción de la función Theta, la simulación y el cálculo de los factores de descuento con las fórmulas del modelo.

# %% [markdown]
# ### Función $\theta$

# %% [markdown]
# Se obtienen los valores de la curva cero cupón.

# %%
curva = pd.read_excel('data/20201012_built_sofr_zero.xlsx')

# %%
curva.tail().style.format(frmt)
# Out:
# <style  type="text/css" >
# </style><table id="T_8d3218ae_2346_11eb_99dc_02cba411ec9d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >plazo</th>        <th class="col_heading level0 col1" >tasa</th>        <th class="col_heading level0 col2" >df</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d3218ae_2346_11eb_99dc_02cba411ec9dlevel0_row0" class="row_heading level0 row0" >28</th>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow0_col0" class="data row0 col0" >7306</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow0_col1" class="data row0 col1" >0.9253%</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow0_col2" class="data row0 col2" >83.092401%</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3218ae_2346_11eb_99dc_02cba411ec9dlevel0_row1" class="row_heading level0 row1" >29</th>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow1_col0" class="data row1 col0" >9133</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow1_col1" class="data row1 col1" >0.9657%</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow1_col2" class="data row1 col2" >78.533775%</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3218ae_2346_11eb_99dc_02cba411ec9dlevel0_row2" class="row_heading level0 row2" >30</th>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow2_col0" class="data row2 col0" >10957</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow2_col1" class="data row2 col1" >0.9881%</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow2_col2" class="data row2 col2" >74.332619%</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3218ae_2346_11eb_99dc_02cba411ec9dlevel0_row3" class="row_heading level0 row3" >31</th>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow3_col0" class="data row3 col0" >14610</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow3_col1" class="data row3 col1" >0.9408%</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow3_col2" class="data row3 col2" >68.619685%</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3218ae_2346_11eb_99dc_02cba411ec9dlevel0_row4" class="row_heading level0 row4" >32</th>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow4_col0" class="data row4 col0" >18262</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow4_col1" class="data row4 col1" >0.8464%</td>
#                         <td id="T_8d3218ae_2346_11eb_99dc_02cba411ec9drow4_col2" class="data row4 col2" >65.475678%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Por comodidad reescribamos la fórmula para la función $\theta_{t}$:
#
# $$
# \begin{equation}
# \theta_{t}=\frac{\partial f(0,t)}{\partial t}+\gamma^*f(0,t)+\frac{\sigma^2}{2\gamma^*}\left[1-\exp(-2\gamma^*t)\right]
# \end{equation}
# $$

# %% [markdown]
# Necesitamos una representación en tiempo contínuo de la curva para poder calcular $f(0,t)$ y su derivada. Para eso, vamos a utilizar el objeto `interp1d` de `scipy.interpolate` que permite definir las abcisas de la curva como $t\in\mathbb{R}$.

# %%
curva['t'] = curva['plazo'] / 365.0

# %%
curva['rate'] = (1 / curva['df'])**(365.0 / curva['plazo']) - 1

# %% [markdown]
# A continuación, se construye el objeto:

# %%
zcurva = interp1d(curva['t'], curva['rate'], kind='cubic',
                  fill_value="extrapolate")

# %% [markdown]
# Veamos un gráfico:

# %%
steps_per_year = 365
years = 20
dt = 1 / steps_per_year
result = []
for i in range(0, steps_per_year * years):
    result.append((i * dt, zcurva(i * dt)))
df_result = pd.DataFrame(result, columns=['plazo', 'tasa'])

# %%
fig = px.line(
    df_result,
    x='plazo',
    y='tasa',
    title=f'Curva Interpolada'
)
fig.show()
# Out:
# <div>
#
#
#             <div id="43446dc7-4005-4019-bb79-506b50b8e1be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43446dc7-4005-4019-bb79-506b50b8e1be")) {
#                     Plotly.newPlot(
#                         '43446dc7-4005-4019-bb79-506b50b8e1be',
#                         [{"hovertemplate": "plazo=%{x}<br>tasa=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": [0.0, 0.0027397260273972603, 0.005479452054794521, 0.008219178082191782, 0.010958904109589041, 0.0136986301369863, 0.016438356164383564, 0.019178082191780823, 0.021917808219178082, 0.024657534246575342, 0.0273972602739726, 0.030136986301369864, 0.03287671232876713, 0.03561643835616438, 0.038356164383561646, 0.0410958904109589, 0.043835616438356165, 0.04657534246575343, 0.049315068493150684, 0.052054794520547946, 0.0547945205479452, 0.057534246575342465, 0.06027397260273973, 0.06301369863013699, 0.06575342465753425, 0.0684931506849315, 0.07123287671232877, 0.07397260273972603, 0.07671232876712329, 0.07945205479452055, 0.0821917808219178, 0.08493150684931507, 0.08767123287671233, 0.09041095890410959, 0.09315068493150686, 0.0958904109589041, 0.09863013698630137, 0.10136986301369863, 0.10410958904109589, 0.10684931506849316, 0.1095890410958904, 0.11232876712328767, 0.11506849315068493, 0.1178082191780822, 0.12054794520547946, 0.12328767123287672, 0.12602739726027398, 0.12876712328767123, 0.1315068493150685, 0.13424657534246576, 0.136986301369863, 0.13972602739726028, 0.14246575342465753, 0.1452054794520548, 0.14794520547945206, 0.1506849315068493, 0.15342465753424658, 0.15616438356164383, 0.1589041095890411, 0.16164383561643836, 0.1643835616438356, 0.16712328767123288, 0.16986301369863013, 0.1726027397260274, 0.17534246575342466, 0.1780821917808219, 0.18082191780821918, 0.18356164383561643, 0.1863013698630137, 0.18904109589041096, 0.1917808219178082, 0.19452054794520549, 0.19726027397260273, 0.2, 0.20273972602739726, 0.2054794520547945, 0.20821917808219179, 0.21095890410958903, 0.2136986301369863, 0.21643835616438356, 0.2191780821917808, 0.2219178082191781, 0.22465753424657534, 0.2273972602739726, 0.23013698630136986, 0.23287671232876714, 0.2356164383561644, 0.23835616438356164, 0.2410958904109589, 0.24383561643835616, 0.24657534246575344, 0.2493150684931507, 0.25205479452054796, 0.2547945205479452, 0.25753424657534246, 0.2602739726027397, 0.263013698630137, 0.26575342465753427, 0.2684931506849315, 0.27123287671232876, 0.273972602739726, 0.2767123287671233, 0.27945205479452057, 0.2821917808219178, 0.28493150684931506, 0.2876712328767123, 0.2904109589041096, 0.29315068493150687, 0.2958904109589041, 0.29863013698630136, 0.3013698630136986, 0.3041095890410959, 0.30684931506849317, 0.3095890410958904, 0.31232876712328766, 0.3150684931506849, 0.3178082191780822, 0.32054794520547947, 0.3232876712328767, 0.32602739726027397, 0.3287671232876712, 0.3315068493150685, 0.33424657534246577, 0.336986301369863, 0.33972602739726027, 0.3424657534246575, 0.3452054794520548, 0.34794520547945207, 0.3506849315068493, 0.35342465753424657, 0.3561643835616438, 0.3589041095890411, 0.36164383561643837, 0.3643835616438356, 0.36712328767123287, 0.3698630136986301, 0.3726027397260274, 0.37534246575342467, 0.3780821917808219, 0.38082191780821917, 0.3835616438356164, 0.3863013698630137, 0.38904109589041097, 0.3917808219178082, 0.39452054794520547, 0.3972602739726027, 0.4, 0.40273972602739727, 0.4054794520547945, 0.40821917808219177, 0.410958904109589, 0.4136986301369863, 0.41643835616438357, 0.4191780821917808, 0.42191780821917807, 0.4246575342465753, 0.4273972602739726, 0.4301369863013699, 0.4328767123287671, 0.43561643835616437, 0.4383561643835616, 0.4410958904109589, 0.4438356164383562, 0.4465753424657534, 0.44931506849315067, 0.452054794520548, 0.4547945205479452, 0.4575342465753425, 0.4602739726027397, 0.46301369863013697, 0.4657534246575343, 0.4684931506849315, 0.4712328767123288, 0.473972602739726, 0.4767123287671233, 0.4794520547945206, 0.4821917808219178, 0.4849315068493151, 0.4876712328767123, 0.4904109589041096, 0.4931506849315069, 0.4958904109589041, 0.4986301369863014, 0.5013698630136987, 0.5041095890410959, 0.506849315068493 ...

# %% [markdown]
# Se definen 3 funciones `float -> float` para calcular el valor de la tasa, su derivada y su derivada segunda en un tiempo $t>0$. Las dos derivadas se calculan desde la derecha.

# %%
def zrate(t: float) -> float:
    return zcurva(t)


def dzrate(t: float) -> float:
    delta = .0001
    return (zcurva(t + delta) - zrate(t)) / delta


def d2zrate(t: float) -> float:
    delta = .0001
    return (dzrate(t + delta) - dzrate(t)) / delta

# %%
t = 2
print(f'zrate({t:.2f}) = {zrate(t):.4%}')
print(f'dzrate({t:.2f}) = {dzrate(t):.4%}')
print(f'd2zrate({t:.2f}) = {d2zrate(t):.4%}')
# Out:
# zrate(2.00) = 0.0568%
# dzrate(2.00) = -0.0066%
# d2zrate(2.00) = 0.0584%

# %% [markdown]
# Sabemos que:
#
# $$f(0,t)=r(0,t)+t\frac{\partial r(0,t)}{\partial t}$$,
#
# y también que:
#
# $$\frac{\partial f(0,t)}{\partial t}=2\frac{\partial r(0,t)}{\partial t}+t\frac{\partial^2r(0,t)}{\partial t^2}$$

# %% [markdown]
# Podemos ahora definir las funciones `fwd(0,t)` y `dfwd(0,t)`.

# %%
def fwd(t: float) -> float:
    return zrate(t) + t * dzrate(t)

def dfwd(t: float) -> float:
    return 2 * dzrate(t) + t * d2zrate(t)

# %%
print(f'fwd({t:.2f}) = {fwd(t):.4%}')
print(f'dfwd({t:.2f}) = {dfwd(t):.4%}')
# Out:
# fwd(2.00) = 0.0436%
# dfwd(2.00) = 0.1037%

# %% [markdown]
# Con esto, podemos ya escribir una expresión para la función Theta. Definamos un valor para $\sigma$ y $\gamma^*$:

# %%
sigma = .015
gamma = .5
r0 = zrate(0)

# %%
def theta(t: float) -> float:
    aux = (sigma ** 2) / (2.0 * gamma) * (1 - math.exp(-2.0 * gamma * t))
    return dfwd(t) + gamma * fwd(t) + aux

# %%
print(f'theta({t:.2f}) = {theta(t):.4%}')
# Out:
# theta(2.00) = 0.1449%

# %% [markdown]
# Grafiquemos la función:

# %%
thetas = []
dt = 1 / 365.0
for i in range(0, 366):
    t = i * dt
    thetas.append((i * dt, theta(t)))
df_theta = pd.DataFrame(thetas, columns=['t', 'theta'])

# %%
fig = px.line(
    df_theta,
    x='t',
    y='theta',
    title=f'Función theta(t)'
)
fig.show()
# Out:
# <div>
#
#
#             <div id="8ed5469f-e6e0-442f-8298-d91176befa9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ed5469f-e6e0-442f-8298-d91176befa9b")) {
#                     Plotly.newPlot(
#                         '8ed5469f-e6e0-442f-8298-d91176befa9b',
#                         [{"hovertemplate": "t=%{x}<br>theta=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.0, 0.0027397260273972603, 0.005479452054794521, 0.008219178082191782, 0.010958904109589041, 0.0136986301369863, 0.016438356164383564, 0.019178082191780823, 0.021917808219178082, 0.024657534246575342, 0.0273972602739726, 0.030136986301369864, 0.03287671232876713, 0.03561643835616438, 0.038356164383561646, 0.0410958904109589, 0.043835616438356165, 0.04657534246575343, 0.049315068493150684, 0.052054794520547946, 0.0547945205479452, 0.057534246575342465, 0.06027397260273973, 0.06301369863013699, 0.06575342465753425, 0.0684931506849315, 0.07123287671232877, 0.07397260273972603, 0.07671232876712329, 0.07945205479452055, 0.0821917808219178, 0.08493150684931507, 0.08767123287671233, 0.09041095890410959, 0.09315068493150686, 0.0958904109589041, 0.09863013698630137, 0.10136986301369863, 0.10410958904109589, 0.10684931506849316, 0.1095890410958904, 0.11232876712328767, 0.11506849315068493, 0.1178082191780822, 0.12054794520547946, 0.12328767123287672, 0.12602739726027398, 0.12876712328767123, 0.1315068493150685, 0.13424657534246576, 0.136986301369863, 0.13972602739726028, 0.14246575342465753, 0.1452054794520548, 0.14794520547945206, 0.1506849315068493, 0.15342465753424658, 0.15616438356164383, 0.1589041095890411, 0.16164383561643836, 0.1643835616438356, 0.16712328767123288, 0.16986301369863013, 0.1726027397260274, 0.17534246575342466, 0.1780821917808219, 0.18082191780821918, 0.18356164383561643, 0.1863013698630137, 0.18904109589041096, 0.1917808219178082, 0.19452054794520549, 0.19726027397260273, 0.2, 0.20273972602739726, 0.2054794520547945, 0.20821917808219179, 0.21095890410958903, 0.2136986301369863, 0.21643835616438356, 0.2191780821917808, 0.2219178082191781, 0.22465753424657534, 0.2273972602739726, 0.23013698630136986, 0.23287671232876714, 0.2356164383561644, 0.23835616438356164, 0.2410958904109589, 0.24383561643835616, 0.24657534246575344, 0.2493150684931507, 0.25205479452054796, 0.2547945205479452, 0.25753424657534246, 0.2602739726027397, 0.263013698630137, 0.26575342465753427, 0.2684931506849315, 0.27123287671232876, 0.273972602739726, 0.2767123287671233, 0.27945205479452057, 0.2821917808219178, 0.28493150684931506, 0.2876712328767123, 0.2904109589041096, 0.29315068493150687, 0.2958904109589041, 0.29863013698630136, 0.3013698630136986, 0.3041095890410959, 0.30684931506849317, 0.3095890410958904, 0.31232876712328766, 0.3150684931506849, 0.3178082191780822, 0.32054794520547947, 0.3232876712328767, 0.32602739726027397, 0.3287671232876712, 0.3315068493150685, 0.33424657534246577, 0.336986301369863, 0.33972602739726027, 0.3424657534246575, 0.3452054794520548, 0.34794520547945207, 0.3506849315068493, 0.35342465753424657, 0.3561643835616438, 0.3589041095890411, 0.36164383561643837, 0.3643835616438356, 0.36712328767123287, 0.3698630136986301, 0.3726027397260274, 0.37534246575342467, 0.3780821917808219, 0.38082191780821917, 0.3835616438356164, 0.3863013698630137, 0.38904109589041097, 0.3917808219178082, 0.39452054794520547, 0.3972602739726027, 0.4, 0.40273972602739727, 0.4054794520547945, 0.40821917808219177, 0.410958904109589, 0.4136986301369863, 0.41643835616438357, 0.4191780821917808, 0.42191780821917807, 0.4246575342465753, 0.4273972602739726, 0.4301369863013699, 0.4328767123287671, 0.43561643835616437, 0.4383561643835616, 0.4410958904109589, 0.4438356164383562, 0.4465753424657534, 0.44931506849315067, 0.452054794520548, 0.4547945205479452, 0.4575342465753425, 0.4602739726027397, 0.46301369863013697, 0.4657534246575343, 0.4684931506849315, 0.4712328767123288, 0.473972602739726, 0.4767123287671233, 0.4794520547945206, 0.4821917808219178, 0.4849315068493151, 0.4876712328767123, 0.4904109589041096, 0.4931506849315069, 0.4958904109589041, 0.4986301369863014, 0.5013698630136987, 0.5041095890410959, 0. ...

# %% [markdown]
# ### Simulación

# %% [markdown]
# Finalmente, podemos simular.

# %%
def sim_hw(gamma: float, sigma: float, theta: float, r0: float,
           num_steps: int, seed = None) -> List[Tuple[float, float]]:
    r = r0
    dt = 1 / 264.0
    sqdt = math.sqrt(dt)
    sim = [(0, r0)]
    rnd.seed(seed)
    for i in range(1, num_steps + 1):
        # print(str(r))
        epsilon = rnd.normal()
        r = r + (theta((i - 1) * dt) - gamma * r) * dt + sigma * sqdt * epsilon
        sim.append((i * dt, r))
        # print(str(theta((i - 1) * dt)) + "\t" + str(epsilon) + "\t" + str(r) )
    return sim

# %%
dt = 1 / 264.0
sim = sim_hw(gamma, sigma, theta, r0, 264, 1000)

# %%
df_sim = pd.DataFrame(sim, columns=['t', 'tasa'])

# %%
fig = px.line(
    df_sim,
    x='t',
    y='tasa',
    title=f'Simulación Hull-White'
)
fig.show()
# Out:
# <div>
#
#
#             <div id="390736a9-2f28-4ff8-a331-e150cfacca04" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("390736a9-2f28-4ff8-a331-e150cfacca04")) {
#                     Plotly.newPlot(
#                         '390736a9-2f28-4ff8-a331-e150cfacca04',
#                         [{"hovertemplate": "t=%{x}<br>tasa=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "h", "showlegend": false, "type": "scatter", "x": [0.0, 0.003787878787878788, 0.007575757575757576, 0.011363636363636364, 0.015151515151515152, 0.01893939393939394, 0.022727272727272728, 0.026515151515151516, 0.030303030303030304, 0.03409090909090909, 0.03787878787878788, 0.04166666666666667, 0.045454545454545456, 0.04924242424242424, 0.05303030303030303, 0.05681818181818182, 0.06060606060606061, 0.06439393939393939, 0.06818181818181818, 0.07196969696969698, 0.07575757575757576, 0.07954545454545454, 0.08333333333333334, 0.08712121212121213, 0.09090909090909091, 0.0946969696969697, 0.09848484848484848, 0.10227272727272728, 0.10606060606060606, 0.10984848484848485, 0.11363636363636365, 0.11742424242424243, 0.12121212121212122, 0.125, 0.12878787878787878, 0.13257575757575757, 0.13636363636363635, 0.14015151515151517, 0.14393939393939395, 0.14772727272727273, 0.15151515151515152, 0.1553030303030303, 0.1590909090909091, 0.16287878787878787, 0.16666666666666669, 0.17045454545454547, 0.17424242424242425, 0.17803030303030304, 0.18181818181818182, 0.1856060606060606, 0.1893939393939394, 0.19318181818181818, 0.19696969696969696, 0.20075757575757577, 0.20454545454545456, 0.20833333333333334, 0.21212121212121213, 0.2159090909090909, 0.2196969696969697, 0.22348484848484848, 0.2272727272727273, 0.23106060606060608, 0.23484848484848486, 0.23863636363636365, 0.24242424242424243, 0.24621212121212122, 0.25, 0.2537878787878788, 0.25757575757575757, 0.26136363636363635, 0.26515151515151514, 0.2689393939393939, 0.2727272727272727, 0.27651515151515155, 0.28030303030303033, 0.2840909090909091, 0.2878787878787879, 0.2916666666666667, 0.29545454545454547, 0.29924242424242425, 0.30303030303030304, 0.3068181818181818, 0.3106060606060606, 0.3143939393939394, 0.3181818181818182, 0.32196969696969696, 0.32575757575757575, 0.32954545454545453, 0.33333333333333337, 0.33712121212121215, 0.34090909090909094, 0.3446969696969697, 0.3484848484848485, 0.3522727272727273, 0.3560606060606061, 0.35984848484848486, 0.36363636363636365, 0.36742424242424243, 0.3712121212121212, 0.375, 0.3787878787878788, 0.38257575757575757, 0.38636363636363635, 0.39015151515151514, 0.3939393939393939, 0.39772727272727276, 0.40151515151515155, 0.40530303030303033, 0.4090909090909091, 0.4128787878787879, 0.4166666666666667, 0.42045454545454547, 0.42424242424242425, 0.42803030303030304, 0.4318181818181818, 0.4356060606060606, 0.4393939393939394, 0.4431818181818182, 0.44696969696969696, 0.45075757575757575, 0.4545454545454546, 0.45833333333333337, 0.46212121212121215, 0.46590909090909094, 0.4696969696969697, 0.4734848484848485, 0.4772727272727273, 0.4810606060606061, 0.48484848484848486, 0.48863636363636365, 0.49242424242424243, 0.4962121212121212, 0.5, 0.5037878787878788, 0.5075757575757576, 0.5113636363636364, 0.5151515151515151, 0.5189393939393939, 0.5227272727272727, 0.5265151515151515, 0.5303030303030303, 0.5340909090909091, 0.5378787878787878, 0.5416666666666666, 0.5454545454545454, 0.5492424242424243, 0.5530303030303031, 0.5568181818181819, 0.5606060606060607, 0.5643939393939394, 0.5681818181818182, 0.571969696969697, 0.5757575757575758, 0.5795454545454546, 0.5833333333333334, 0.5871212121212122, 0.5909090909090909, 0.5946969696969697, 0.5984848484848485, 0.6022727272727273, 0.6060606060606061, 0.6098484848484849, 0.6136363636363636, 0.6174242424242424, 0.6212121212121212, 0.625, 0.6287878787878788, 0.6325757575757576, 0.6363636363636364, 0.6401515151515151, 0.6439393939393939, 0.6477272727272727, 0.6515151515151515, 0.6553030303030303, 0.6590909090909091, 0.6628787878787878, 0.6666666666666667, 0.6704545454545455, 0.6742424242424243, 0.6780303030303031, 0.6818181818181819, 0.6856060606060607, 0.6893939393939394, 0.6931818181818182, 0.696969696969697, 0.7007575757575758, 0.7045454545454546, 0.708 ...

# %%
print(f'plazo: {sim[263][0]:.4f},\ntasa: {sim[263][1]:.4%}')
# Out:
# plazo: 0.9962,
# tasa: -1.8371%

# %% [markdown]
# ### Bono Cupón Cero

# %% [markdown]
# Función $B$ de la fórmula para un bono cupón cero:

# %%
def b_hw(gamma: float, t: float, T: float) -> float:
    """
    gamma : para 
    sigma: 
    t : plazo de....
    T: plazo ....
    """
    aux = 1 - math.exp(- gamma * (T - t))
    return aux / gamma

# %% [markdown]
# Función $A$ de la fórmula para un bono cupón cero:

# %%
def a_hw(zrate: float, fwd: float, gamma: float, sigma: float, t: float, T: float, verbose = False):
    """
    verbose: cuando es True imprime los valores de c1, c2 y c3.
    """
    b = b_hw(gamma, t, T)
    dfT = math.exp(-zrate(T) * T)
    dft = math.exp(-zrate(t) * t)
    c1 = math.log(dfT / dft)
    c2 = b * fwd(t)
    c3 = (sigma**2) / (4 * gamma) * (b**2) * (1 - math.exp(-2 * gamma * t))
    if verbose:
        print("c1: " + str(c1))
        print("c2: " + str(c2))
        print("c3: " + str(c3))
    return c1 + c2 - c3

# %% [markdown]
# Factor de descuento según HW.

# %%
def zero_hw(r: float, gamma: float, sigma: float,
            zrate: float, fwd: float, t: float, T: float) -> float:
    a = a_hw(zrate, fwd, gamma, sigma, t, T)
    b = b_hw(gamma, t, T)
    return math.exp(a - b * r)

# %% [markdown]
# Verifiquemos que los valores que entrega la fórmula de HW coinciden con los datos de la curva:

# %%
r0 = zrate(0)
print(f"r0:        {r0:.8%}")
t = 0
T = 1.1234
z = zero_hw(r0, gamma, sigma, zrate, fwd, t, T)
print(f"df hw:    {z:.8%}")
print(f"df curva: {math.exp(-zrate(T) * T):.8%}")
# Out:
# r0:        0.07884508%
# df hw:    99.92235606%
# df curva: 99.92235606%

# %% [markdown]
# ### Ejercicio de Valorización

# %% [markdown]
# Vamos a valorizar, en 1Y más, un bono semestral a tasa fija del 5% que en 1Y más le quedarán 4Y. Podemos además hacer el ejercicio de verificar la simulación calculando los valores de los bonos cero cupón usando la simulación.
#
# Utilizaremos la siguiente función:

# %%
def bono_tasa_fija(start_time: float, yf: float,
                   num_cupones: int, valor_tasa: float) -> List[Tuple[float, float]]:
    """
    Retorna los plazos y flujos de un bono a tasa fija bullet con nominal = 0.
    
    params:
    
    - start_time: fecha (expresada en fracción de año) en que comienza el devengo del primer cupón.
    - yf: fracción de año que representa la periodicidad del bono (yf = .5 -> bono semestral).
    - num_cupones: número de cupones del bono
    - valor_tasa: valor de la tasa fija del bono. Los intereses se calculan de forma lineal.
    
    return:
    
    - Una `list` de `tuple` con la fecha de pago del cupón (como instante de tiempo) y el monto del cupón.
    """
    result = []
    flujo = valor_tasa * yf
    for i in range(1, num_cupones + 1):
        if i == num_cupones:
            flujo += 1.0
        result.append((i * yf + start_time, flujo))
    return result

# %%
start_time = 1.5
yf = .5
tasa = .05
num_cupones = 8
bf = bono_tasa_fija(start_time, yf, num_cupones, tasa)
bf
# Out:
# [(2.0, 0.025),
#  (2.5, 0.025),
#  (3.0, 0.025),
#  (3.5, 0.025),
#  (4.0, 0.025),
#  (4.5, 0.025),
#  (5.0, 0.025),
#  (5.5, 1.025)]

# %%
r1Y = sim[264][1]
print(f'Tasa instantánea simulada a 1Y: {r1Y:.6%}')
# Out:
# Tasa instantánea simulada a 1Y: -1.906778%

# %% [markdown]
# ¿Cuál es la curva de factores de descuento en t = 1Y en esta simulación?

# %%
t = 1
zeros_1Y = []
for plazo in [b[0] for b in bf]:
    zeros_1Y.append(zero_hw(r1Y, gamma, sigma, zrate, fwd, t, plazo))
print(zeros_1Y)
# Out:
# [1.0151305857938773, 1.020094537621821, 1.0235079895437473, 1.025567030063376, 1.026446416893182, 1.0262951649757672, 1.0251582633566996, 1.0230557617338862]

# %% [markdown]
# ¿Cuál es el valor presente?

# %%
vp = np.dot(zeros_1Y, [b[1] for b in bf])
print(f"vp: {vp:.6%}")
# Out:
# vp: 122.768716%

# %% [markdown]
# Chequear que el operador `np.dot` haga lo que creemos que está haciendo:

# %%
vp1 = 0
for y in zip([b[1] for b in bf], zeros_1Y):
    vp1 += y[0] * y[1]
print(f"vp1: {vp1:.6%}")
# Out:
# vp1: 122.768716%

# %% [markdown]
# ### No Terminado

# %%
def sim_hw_many(gamma, sigma, theta, r0, num_sim, num_steps, seed = None):
    dt = 1/264.0
    # Calcula los números aleatorios
    alea = np.zeros((num_sim, num_steps))
    rnd.seed(seed)
    # for i in range(0, 5000):
    #    rnd.normal()
    for i in range(0, num_sim):
        for j in range(0, num_steps):
            alea[i][j] = rnd.normal()
            
    # Calcula los valores de Theta. Theta sólo depende del tiempo, no de la simulación. 
    theta_array = np.zeros(num_steps)
    for i in range(0, num_steps):
        theta_array[i] = theta(i * dt)
    
    # Simula las trayectorias
    sqdt_sigma = math.sqrt(dt) * sigma
    gamma_dt = gamma * dt
    sim = np.zeros((num_sim, num_steps))
    for i in range(0, num_sim):
        sim[i][0] = r0
        r = r0
        for j in range(1, num_steps):
            # print(str(r))
            r = r + theta_array[j - 1] * dt - gamma_dt * r + sqdt_sigma * alea[i][j - 1]
            sim[i][j] = r
            # print(str(theta_array[j - 1]) + "\t" + str(alea[i][j - 1]) + "\t" + str(r) )
    return sim

# %%
num_sim = 10
def sim_many(num_sim, r0, gamma, sigma, zrate, fwd, theta, bf):
    result = []
    for i in range(0, num_sim):
        r1y = sim_hw(gamma, sigma, theta, r0, 264)[263]
        zeros_1Y = []
        for plazo in bf[0]:
            zeros_1Y.append(zero_hw(r1y, gamma, sigma, zrate, fwd, t, plazo))
        vp = np.dot(zeros_1Y, bf[1])
        result.append(vp)
    return result

res = sim_many(num_sim, r0, gamma, sigma, zrate, fwd, theta, bf)
res
# Out:
# [1.1279540277552287,
#  1.1017071334219528,
#  1.109978338654758,
#  1.129794026792734,
#  1.1089066369872622,
#  1.1037275422507045,
#  1.090911338993188,
#  1.1169754223503474,
#  1.1028002001274457,
#  1.1181127285470778]

# %%
num_sim = 1000
# dfs = 0
t = .25
sim = 0
seed = None
num_steps = int(t*264)
print("num_steps: " + str(num_steps))
for i in range(0, num_sim):
    sim += math.exp(np.sum(- dt * np.array(
        sim_hw(gamma, sigma, theta, r0, num_steps, seed))))
    # dfs += math.exp(np.sum(sim))
ez = sim / num_sim
z_curva = math.exp(-zrate(t) * t)
print("ez: " + str(ez))
print("z_curva: " + str(z_curva))
# Out:
# num_steps: 66
# ez: 0.997597204287458
# z_curva: 0.9976549482230134

# %%
num_sim = 50000
t = .25
num_steps = int(t * 264)
print("num_steps: " + str(num_steps))
seed = None
df = 0
s = sim_hw_many(gamma, sigma, theta, r0, num_sim, num_steps, seed)
for sim in s:
    # print(len(sim))
    df += math.exp(-dt * np.sum(sim))
ez = df / num_sim
z_curva = math.exp(-zrate(t) * t)
print("ez: " + str(ez))
print("z_curva: " + str(z_curva))
print(t)
# Out:
# num_steps: 66
# ez: 0.9976520059005399
# z_curva: 0.9976549482230134
# 0.25
